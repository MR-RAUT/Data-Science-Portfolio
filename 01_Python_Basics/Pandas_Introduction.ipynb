# %%
import pandas as pd

# %%
df = pd.read_csv("Data\Salaries.csv")

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#head function is give as first 5 record in dataset
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#this is provide as first 10 record form data set
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
print(df)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
# that function give me as last 5 record of data set
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
#that is give as botoms 10 record for data set
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
# that function give me information abaut the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
#that is function usde the check the null valus ar present in data set
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
 df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
#that is show the sheape of the data 
df.shape
# Out:
# (78, 6)

# %%
#that fitures give the names of columns in data set
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
# that function provide a all numarical columns wich is present in data set
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
# that give a minimum valus of data set
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
# that is provide total numbar of obsevation ech point in rank columns
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
# that is give as maximum valus
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
# finding the mean of salary
df['salary'].mean()
# Out:
# np.float64(108023.78205128205)

# %%
# findinng the midean of salary
df['salary'].median()
# Out:
# 104671.0

# %%
# finding the mode of salary
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
# that is more than one columns
df[['salary','phd']]
# Out:
#     salary  phd
# 0   186960   56
# 1    93000   12
# 2   110515   23
# 3   131205   40
# 4   104800   20
# 5   122400   20
# 6    81285   20
# 7   126300   18
# 8    94350   29
# 9    57800   51
# 10  128250   39
# 11  134778   23
# 12   88000    1
# 13  162200   35
# 14  153750   25
# 15  150480   17
# 16   75044    8
# 17   92000    4
# 18  107300   19
# 19  150500   29
# 20   92000    4
# 21  103106   33
# 22   73000    4
# 23   85000    2
# 24   91100   30
# 25   99418   35
# 26  148750   38
# 27  155865   45
# 28   91300    7
# 29  123683   21
# 30  107008    9
# 31  155750   22
# 32  103275   27
# 33  120000   18
# 34  119800   12
# 35  126933   28
# 36  146856   45
# 37  102000   20
# 38   91000    4
# 39  129000   18
# 40  137000   39
# 41   74830   13
# 42   80225    4
# 43   77000    5
# 44  151768   23
# 45  140096   25
# 46   74692   11
# 47  103613   11
# 48  111512   17
# 49  122960   17
# 50   97032   10
# 51  127512   20
# 52  105000   12
# 53   73500    5
# ...

# %%
df[['salary','phd']].mean()
# Out:
# salary    108023.782051
# phd           19.705128
# dtype: float64

# %%
df[['salary','phd','service']]
# Out:
#     salary  phd  service
# 0   186960   56       49
# 1    93000   12        6
# 2   110515   23       20
# 3   131205   40       31
# 4   104800   20       18
# 5   122400   20       20
# 6    81285   20       17
# 7   126300   18       18
# 8    94350   29       19
# 9    57800   51       51
# 10  128250   39       33
# 11  134778   23       23
# 12   88000    1        0
# 13  162200   35       33
# 14  153750   25       19
# 15  150480   17        3
# 16   75044    8        3
# 17   92000    4        0
# 18  107300   19        7
# 19  150500   29       27
# 20   92000    4        4
# 21  103106   33       30
# 22   73000    4        2
# 23   85000    2        0
# 24   91100   30       23
# 25   99418   35       31
# 26  148750   38       19
# 27  155865   45       43
# 28   91300    7        2
# 29  123683   21       20
# 30  107008    9        7
# 31  155750   22       21
# 32  103275   27       19
# 33  120000   18       18
# 34  119800   12        8
# 35  126933   28       23
# ...

# %%
# that function give as all rows and columns

#iloc[:,:] finction is index location that help to etract the particular data in dataset

df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
# first 50 record on dataset
df.iloc[0:50,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#thsi finction is give as the first 50 record from 0 and 2 columns
df.iloc[0:50,0:2]
# Out:
#          rank discipline
# 0        Prof          B
# 1        Prof          A
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# 5        Prof          A
# 6   AssocProf          A
# 7        Prof          A
# 8        Prof          A
# 9        Prof          A
# 10       Prof          B
# 11       Prof          B
# 12   AsstProf          B
# 13       Prof          B
# 14       Prof          B
# 15       Prof          B
# 16   AsstProf          B
# 17   AsstProf          B
# 18       Prof          A
# 19       Prof          A
# 20   AsstProf          B
# 21       Prof          A
# 22   AsstProf          A
# 23   AsstProf          A
# 24       Prof          A
# 25       Prof          B
# 26       Prof          A
# 27       Prof          A
# 28   AsstProf          B
# 29       Prof          B
# 30  AssocProf          B
# 31       Prof          B
# 32       Prof          A
# 33       Prof          B
# 34  AssocProf          B
# 35       Prof          B
# ...

# %%
# is give list of columns record in dataset like 1,3,5
df.iloc[0:50,[1,3,5]]
# Out:
#    discipline  service  salary
# 0           B       49  186960
# 1           A        6   93000
# 2           A       20  110515
# 3           A       31  131205
# 4           B       18  104800
# 5           A       20  122400
# 6           A       17   81285
# 7           A       18  126300
# 8           A       19   94350
# 9           A       51   57800
# 10          B       33  128250
# 11          B       23  134778
# 12          B        0   88000
# 13          B       33  162200
# 14          B       19  153750
# 15          B        3  150480
# 16          B        3   75044
# 17          B        0   92000
# 18          A        7  107300
# 19          A       27  150500
# 20          B        4   92000
# 21          A       30  103106
# 22          A        2   73000
# 23          A        0   85000
# 24          A       23   91100
# 25          B       31   99418
# 26          A       19  148750
# 27          A       43  155865
# 28          B        2   91300
# ...

# %%
# that is the kurtasis colculation function 
df['salary'].kurt()
# Out:
# np.float64(-0.4017126758820546)

# %%
# that is the skewnes calculation function
df['salary'].skew()
# Out:
# np.float64(0.45210256755588096)

# %%
df.kurt(numeric_only=True)
# Out:
# phd        0.042504
# service    0.608981
# salary    -0.401713
# dtype: float64

# %%
df.skew(numeric_only=True)
# Out:
# phd        0.634366
# service    0.913750
# salary     0.452103
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# phd        1.562106e+02
# service    1.473740e+02
# salary     8.005313e+08
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.groupby(by='rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(by='rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
# that function location that give the particular locatuin value in dataset
#ex: first index of salary is (186960)
df.loc[0,'salary']
# Out:
# np.int64(186960)
