# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"Data\University.csv")

# %% [markdown]
# # Visaulization

# %%
df
# Out:
#             Univ State   SAT  Top10  Accept  SFRatio Expenses  GradRate
# 0          Brown    RI  1310     89      22       13   22,704        94
# 1        CalTech    CA  1415    100      25        6   63,575        81
# 2            CMU    PA  1260     62      59        9   25,026        72
# 3       Columbia    NY  1310     76      24       12   31,510        88
# 4        Cornell    NY  1280     83      33       13   21,864        90
# 5      Dartmouth    NH  1340     89      23       10   32,162        95
# 6           Duke    NC  1315     90      30       12   31,585        95
# 7     Georgetown    DC  1255     74      24       12   20,126        92
# 8        Harvard    MA  1400     91      14       11   39,525        97
# 9   JohnsHopkins    MD  1305     75      44        7   58,691        87
# 10           MIT    MA  1380     94      30       10   34,870        91
# 11  Northwestern    IL  1260     85      39       11   28,052        89
# ...

# %%
plt.hist(df["SAT"])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["SAT"])
plt.xlabel("SAT")
plt.ylabel("Frequncy")
plt.title("Histogram of SAT")
plt.show()

# %%
import seaborn as sns
sns.histplot(df["SAT"])
plt.show()

# %%
sns.histplot(df["Accept"])
plt.show()

# %%
sns.histplot(df['Expenses'])
plt.show()

# %%
plt.plot(df['SAT'],df['Accept'],'bo')
plt.xlabel('SAT')
plt.ylabel('Accept')
plt.title('satterplot bitween SAT VS Accept')
# Out:
# Text(0.5, 1.0, 'satterplot bitween SAT VS Accept')

# %%
plt.plot(df['SAT'],df['Accept'],'rs')
plt.xlabel('SAT')
plt.ylabel('Accept')
plt.title('satterplot bitween SAT VS Accept')
# Out:
# Text(0.5, 1.0, 'satterplot bitween SAT VS Accept')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df.iloc[:,1:5])

# %%
plt.boxplot(df['SAT'])
plt.show()

# %%
plt.boxplot(df['Accept'])
plt.xlabel("Accept")
plt.ylabel("Valus")
plt.title("Boxplot for Accept")
plt.show()

# %%
plt.boxplot(df['Accept'],vert=False)
plt.xlabel("Accept")
plt.ylabel("valus")
plt.title("Boxplot of Accept")
plt.show()

# %%
df['Expenses'] = df['Expenses'].str.replace(',', '', regex=False).astype(float)
plt.boxplot(df['Expenses'],vert=False)
plt.xlabel("Expenses")
plt.ylabel("valus")
plt.title("Boxplot of Expenses")
plt.show()

# %%
import warnings 
warnings.filterwarnings('ignore') 
sns.distplot(df['SAT'])
plt.show()

# %%
sns.distplot(df['Accept'])
plt.show()

# %% [markdown]
# # Dupalicates

# %%
# duplicate
dup = pd.DataFrame({'col1':['A','B','A','B'],'col2':[1,2,1,2]})

# %%
dup
# Out:
#   col1  col2
# 0    A     1
# 1    B     2
# 2    A     1
# 3    B     2

# %%
dup.shape
# Out:
# (4, 2)

# %%
# this function is chack the duplicat in datasets in boolian valus
dup.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
# show the duplicated atuale valus
dup[dup.duplicated()]
# Out:
#   col1  col2
# 2    A     1
# 3    B     2

# %%
# Drop the duplicate in the dataset
dup.drop_duplicates()
# Out:
#   col1  col2
# 0    A     1
# 1    B     2

# %%
dup1= dup.drop_duplicates()
dup1
print(dup1)
# Out:
#   col1  col2
# 0    A     1
# 1    B     2

# %% [markdown]
# # NumPy Array / Numaric python

# %%
import numpy as np

# %%
# Tow dimention array
a = np.array([(1,2,3,4),(4,5,6,7)])
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (2, 4)

# %%
a.size
# Out:
# 8

# %%
# resize the array
a=a.reshape(4,2)
a
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
a.shape
# Out:
# (4, 2)

# %%
# one dimention array
a=np.array([1,2,3,4])
a.shape
# Out:
# (4,)

# %%
a.min()
# Out:
# np.int64(1)

# %%
a.max()
# Out:
# np.int64(4)

# %%
a.sum()
# Out:
# np.int64(10)

# %%
a.prod()
# Out:
# np.int64(24)

# %%
# thsi give as particular index valus
print(a[0])
a[1]
a[2]
a[3]
# Out:
# 1
# np.int64(4)

# %%
a = np.array([(1,2,3,4),(4,5,6,7)])
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
# thsi uesd for he tow dime array
a[0,2]
a[1,1]
# Out:
# np.int64(5)

# %%
# row wise adintion is row wise opretion axis=0
a.sum(axis=0)
# Out:
# array([ 5,  7,  9, 11])

# %%
# colinm wise adintion is colunm wise opretion axis=1
a.sum(axis=1)
# Out:
# array([10, 22])
